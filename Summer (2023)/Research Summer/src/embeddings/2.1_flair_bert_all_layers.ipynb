# %%
# %load_ext autoreload
# %autoreload 2
from IPython.display import display

# %%
import logging
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(message)s", level=logging.INFO, force=True
)

# %%
from flair.embeddings import TransformerWordEmbeddings

model_name = "bert-base-uncased"

params = {
    'model': model_name,
    'use_context': True,
    'layers':'all',
    'layer_mean':True,
    'subtoken_pooling':'mean'
}

embedding = TransformerWordEmbeddings(**params)

# %%
import utils, evaluators
ev = evaluators.FlairEvaluator(embedding, model_name)
ev.load_dataset("../datasets/dataset_1.json")

# %%
ev.reset_evaluator()
evaluation = ev.evaluate()

# %%
st = utils.Statistics(ev)

display("OOV:")
display(st.get_oov())

display("Lost:")
display(st.get_lost())

stats = st.calculate_statistics()
display("Statistics:")
display(stats)

st.display_PRC()
# Out:
# 'OOV:'
# Empty DataFrame
# Columns: [Case ID, Keyword, Word, Classification, Similarity, Lost, OOV]
# Index: []
# 'Lost:'
#       Case ID Keyword      Word  Classification  Similarity  Lost    OOV
# 1477        4    when  (now, 0)               1         NaN  True  False
# 1478        4    when  (now, 1)               1         NaN  True  False
# 'Statistics:'
#                        Threshold  Precision    Recall  F1 Score  Accuracy  \
# Methods
# bert-base-uncased-cos   0.342878   0.768116  0.623529  0.688312  0.968972
#
#                          AUC-PR
# Methods
# bert-base-uncased-cos  0.629446

# %%
import pandas as pd
methods = [member for member in utils.SimilarityFunction]

results = pd.DataFrame()

for method in methods:
    ev.similarity_method = method
    ev.reset_evaluator()
    data = ev.evaluate()
    st = utils.Statistics(ev)
    stats = st.calculate_statistics()
    st.display_PRC()
    results = pd.concat([results, stats])

display(results)
# Out:
#                        Threshold  Precision    Recall  F1 Score  Accuracy  \
# Methods
# bert-base-uncased-cos   0.342878   0.768116  0.623529  0.688312  0.968972
# bert-base-uncased-dot  94.675766   0.684211  0.611765  0.645963  0.963154
# bert-base-uncased-euc   5.950653   0.555556  0.588235  0.571429  0.951519
#
#                          AUC-PR
# Methods
# bert-base-uncased-cos  0.629446
# bert-base-uncased-dot  0.589045
# bert-base-uncased-euc  0.572995
